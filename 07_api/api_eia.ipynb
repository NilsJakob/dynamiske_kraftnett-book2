# %%
import requests

api_url = "https://api.energy-charts.info/v2/public_power?country=se"
response = requests.get(api_url)
print(response.status_code)
# Out:
# 200

# %%
print(response.json())
# Out:
# {'schema_version': '2.0', 'endpoint': 'public_power', 'country': 'se', 'bidding_zone': None, 'timezone': 'Europe/Stockholm', 'resolution': 'PT15M', 'interval_minutes': 15, 'unit': 'MW', 'generated_at': '2026-09-18T12:13:44+02:00', 'available_from': '2026-09-18T00:00:00+02:00', 'available_until': '2026-09-18T10:30:00+02:00', 'series': [{'id': 'cross_border_electricity_trading', 'name': 'Cross border electricity trading'}, {'id': 'nuclear', 'name': 'Nuclear'}, {'id': 'fossil_gas', 'name': 'Fossil gas'}, {'id': 'hydro_water_reservoir', 'name': 'Hydro water reservoir'}, {'id': 'others', 'name': 'Others'}, {'id': 'wind_onshore', 'name': 'Wind onshore'}, {'id': 'solar', 'name': 'Solar'}, {'id': 'load', 'name': 'Load'}, {'id': 'residual_load', 'name': 'Residual load'}, {'id': 'renewable_share_of_load', 'name': 'Renewable share of load', 'unit': '%'}, {'id': 'renewable_share_of_generation', 'name': 'Renewable share of generation', 'unit': '%'}], 'data': [{'timestamp': '2026-09-18T00:00:00+02
# ...
