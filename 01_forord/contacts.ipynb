# %% [markdown]
# # Kontakt meg
#
# My office is B-233, on the 2nd floor in the B-building, just above Café Origo.
#
# Contact:
#
# 📧nils.j.johannesen@usn.no
#
# 📧nils.j.johannesen@uis.no
#
#
# 🌐 [website](https://www.usn.no/english/about/contact-us/employees/nils-jakob-johannesen)
#
# Veibeskrivelse til A-202

# %%
# TEST CELL
from IPython.display import IFrame

IFrame( src="https://use.mazemap.com/embed.html#v=1&amp;campusid=33&amp;zlevel=1&amp;center=5.693201,58.938218&amp;zoom=18&amp;sharepoitype=identifier&amp;sharepoi=A202&amp;utm_medium=iframe", width=900, height=500 )
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://use.mazemap.com/embed.html#v=1&amp;campusid=33&amp;zlevel=1&amp;center=5.693201,58.938218&amp;zoom=18&amp;sharepoitype=identifier&amp;sharepoi=A202&amp;utm_medium=iframe"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
