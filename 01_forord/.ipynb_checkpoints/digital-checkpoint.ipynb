# %% [markdown]
# # Digitalisering
#
# ## Kraftsystemdata
#
# Eksperter på kraftsystemdata annerkjenner de [3D'ene](https://www.sciencedirect.com/science/article/pii/S1364032118304283) (Dekarbonisering, Desentralisering og Digitalisering) som pådrivere for systemforandringer i kraftnettet. Disse og andre [D'frames](https://www.sciencedirect.com/science/article/pii/S2214629621003236#b0140) er analytiske rammer til å forstå trender som styrer store komplekse forandringer i det framtidige kraftnettet. Kraftsystemdata legger frem de underliggende dataen som beskriver selve forandringen. Et dilemma er strømbehovet til komplekse [ki-algoritmer som skal optmalisere strømbruken](https://www.europower.no/digitalisering/ingen-kunstig-intelligens-uten-barekraft-slik-kan-vi-toyle-stromforbruket/2-1-1665594).

# %%
# TEST CELL
from IPython.display import IFrame

IFrame(
    src="https://ourworldindata.org/grapher/data-centers-share-electricity-demand?tab=discrete-bar&time=latest&country=CHN~USA~OWID_WRL~IEA_AFR~IEA_EUR~IEA_MEA~IEA_CSA",
    #loading="lazy" style="width: 100%; height: 600px; border: 0px none;" allow="web-share; clipboard-write",
    width="100%",
    height=600
)
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="https://ourworldindata.org/grapher/data-centers-share-electricity-demand?tab=discrete-bar&time=latest&country=CHN~USA~OWID_WRL~IEA_AFR~IEA_EUR~IEA_MEA~IEA_CSA"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# TEST CELL
from IPython.display import IFrame

IFrame(
    src="https://ourworldindata.org/grapher/energy-consumption-by-source-and-country?stackMode=absolute&country=~NOR&tab=chart",
    width="100%",
    height=600
)
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="https://ourworldindata.org/grapher/energy-consumption-by-source-and-country?stackMode=absolute&country=~NOR&tab=chart"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
