# %% [markdown]
# # Støttelitteratur ELK330
#
# Anbefalt litteratur for emnet

# %%
# TEST CELL
import os
os.listdir("../images")
# Out:
# ['digital_tvilling_PF.pdf',
#  'digital_tvilling_PF.png',
#  'digital_tvilling_PF_resize.png',
#  'digital_tvilling_PF_resize600dpi.png',
#  'eleingbscuis.png',
#  'fp_grainger.jpg',
#  'fp_grainger.png',
#  'fp_overbye.jpg',
#  'fp_python.webp',
#  'PF_Architecture_PF_MultiUser_Edition.svg',
#  'power_grid_sunset.jpg',
#  'stabilitet_diagram.svg']

# %%
# TEST CELL
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("../images/eleingbscuis.png")

fig, ax = plt.subplots(figsize=(8,4))
ax.imshow(img)
ax.axis("off")

plt.figtext(
    0.8, 0.6,
    "Elektroprogrammaet ingeniør \n\n Bachelor UiS",
    fontsize=12
)

plt.show()

# %%
# TEST CELL
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("../images/fp_python.webp")

fig, ax = plt.subplots(figsize=(8,4))
ax.imshow(img)
ax.axis("off")

plt.figtext(
    0.7, 0.6,
    "Python for realfag\n\nav Finn Haugen og Ola Marius Lysaker\n\nDenne boken gir en introduksjon til programmering med Python gjennom eksempler og oppgaver fra realfag.",
    fontsize=12
)

plt.show()

# %%
# TEST CELL
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("../images/fp_grainger.png")

fig, ax = plt.subplots(figsize=(8,4))
ax.imshow(img)
ax.axis("off")

plt.figtext(
    0.7, 0.6,
    "Power System Analysis\n\n av Grainger & Stevenson\n\n ELK250",
    fontsize=12
)

plt.show()

# %%
# TEST CELL
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("../images/fp_overbye.jpg")

fig, ax = plt.subplots(figsize=(8,4))
ax.imshow(img)
ax.axis("off")

plt.figtext(
    0.7, 0.6,
    "Power System Analysis & Design\n\n av Glover/Overbye/Sarma's\n\n ELK250",
    fontsize=12
)

plt.show()
