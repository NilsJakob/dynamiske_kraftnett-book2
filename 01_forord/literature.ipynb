# %% [markdown]
# # Støttelitteratur ELK330
#
# Anbefalt litteratur for emnet.
#
# ELK 330 bygger på alle erfaringer så langt i studieløpet.
#
# En målsetning er å få benyttet tidligere erfaringer, sammensette de på en ny måte, til å oppdage kraftnettet på nytt.
#
# ELK330 bygger både på kunnskaper fra fellesemnene og elkraft-emnene som beskrevet i studieplanen:

# %%
# TEST CELL
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("../images/eleingbscuis.png")

fig, ax = plt.subplots(figsize=(8,4))
ax.imshow(img)
ax.axis("off")

plt.figtext(
    0.8, 0.6,
    "Elektroprogrammet ingeniør \n\n Bachelor UiS",
    fontsize=12
)

plt.show()

# %%
# TEST CELL
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("../images/fp_python.webp")

fig, ax = plt.subplots(figsize=(8,4))
ax.imshow(img)
ax.axis("off")

plt.figtext(
    0.7, 0.6,
    "Python for realfag\n\nav Finn Haugen og Ola Marius Lysaker\n\nDenne boken gir en introduksjon til programmering med Python\ngjennom eksempler og oppgaver fra realfag.",
    fontsize=12
)
plt.figtext(
    0.7, 0.4,
    "DAT120\n\nELK330 kapittel 9: Les og skriv fra/til datafiler",
    fontsize=12
)
plt.show()

# %%
# TEST CELL
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("../images/fp_statistikk.jpg")

fig, ax = plt.subplots(figsize=(8,4))
ax.imshow(img)
ax.axis("off")

plt.figtext(
    0.7, 0.6,
    "Statistikk for universiteteter og høyskoler\n\nav Gunnar G. Løvås\n\nDenne boken gir en introduksjon til programmering med Python\ngjennom eksempler og oppgaver fra realfag.",
    fontsize=12
)
plt.figtext(
    0.7, 0.5,
    "STA 100",
    fontsize=12
)
plt.figtext(
    0.7, 0.3,
    "Kunne bruke enkle metoder for analyse og presentasjon av data\nGrunnleggende sannsynlighetsfordelinger som eksponential-, og normalfordeling.\nKjenne teori for og kunne bruke korrelasjon, regresjonsanalyse og enkel variansanalyse\nKjenne til grunnleggende metoder i maskinlæring",
    fontsize=12
)
plt.figtext(
    0.7, 0.2,
    "Fun Fact: Gunnar er konsernsjef i Statnett",
    fontsize=12
)
plt.show()

# %%
# TEST CELL
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("../images/fp_grainger.png")

fig, ax = plt.subplots(figsize=(8,4))
ax.imshow(img)
ax.axis("off")

plt.figtext(
    0.7, 0.6,
    "Power System Analysis\n\n av Grainger & Stevenson\n\n ELK250",
    fontsize=12
)

plt.show()

# %%
# TEST CELL
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("../images/fp_overbye.jpg")

fig, ax = plt.subplots(figsize=(8,4))
ax.imshow(img)
ax.axis("off")

plt.figtext(
    0.7, 0.6,
    "Power System Analysis & Design\n\n av Glover/Overbye/Sarma's\n\n ELK250",
    fontsize=12
)

plt.show()

# %%
# TEST CELL
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("../images/fp_powerfactory.webp")

fig, ax = plt.subplots(figsize=(8,4))
ax.imshow(img)
ax.axis("off")

plt.figtext(
    0.7, 0.6,
    "Power System Fundamentals with Power Factory\n\n av Bayati & Khan\n\nELK330",
    fontsize=12
)

plt.figtext(
    0.7, 0.5,
    "Explains the modeling and analysis of power systems by PowerFactory\nCovers all the required theory from the most basic level to the practical application in a single volume",
    fontsize=12
)
plt.figtext(
    0.7, 0.2,
    "Power Factory programmet vil bli brukt i kurset",
    fontsize=12
)
plt.show()

# %%
# TEST CELL
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("../images/studyplan.png")

fig, ax = plt.subplots(figsize=(8,4))
ax.imshow(img)
ax.axis("off")

plt.figtext(
    0.9, 0.6,
    "Timeplan 5. semester ingeniør \n\n Bachelor UiS",
    fontsize=12
)

plt.show()
