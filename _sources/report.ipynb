# %% [markdown]
# # Prosjektrapport
# Som beskrevet i emneplan vil 2/5 deler av vurderingsgrunnlaget i ELK330 leveres som rapport.
#
# Det spesifiseres ikke noen antall sider i rapporten, men det vil bli vektlagt:
# Beherske markdown formattering (.md)
#
# Beherske bruk av hyperreferanser
#
# Kildegrunnlag (bibtex i APA format)
# Litteratursøk/literaturliste/litteratursøk
#
# Legge ved git-repo og git log
#
# Gjøre rede for modellering gjort i prosjektet
#
# Studentene skal ved diskusjon og reflektere rundt modellens under- og overrepresentasjon i forhold til kapittel på modeller
#
# simuleringsmodell i power factory (.pfd)
#
# Studentene skal ved diskusjon og refleksjon rundt resultatene identifisere modell i forhold til integrasjon og kompleksitet (ref kapittelet om digitale modeller)
